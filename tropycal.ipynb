# %%
import tropycal.tracks as tracks

# %%
basin = tracks.TrackDataset(basin='north_atlantic')
# Out:
# --> Starting to read in HURDAT2 data
# --> Completed reading in HURDAT2 data (1.57 seconds)

# %%
storm = basin.get_storm(('sandy',2012))

# %%
storm.plot()
# Out:
# <GeoAxes: title={'left': 'Hurricane SANDY', 'right': '22 Oct 2012 – 29 Oct 2012\n100 kt • 940 hPa • 13.7 ACE'}>

# %%
storm.plot_nhc_forecast(forecast=2)
# Out:
# <GeoAxes: title={'left': 'Tropical Storm SANDY', 'right': '40 mph • 999 hPa • Forecast #2\nForecast Issued: 2100 UTC 22 Oct 2012'}>
